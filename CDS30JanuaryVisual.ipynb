# %% [markdown]
# <a href="https://colab.research.google.com/github/DattaIn/idatta.github.io/blob/master/CDS30JanuaryVisual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/mdhabeebvulla/samples/master/datasetsiris.csv
# Out:
# --2024-01-17 22:17:58--  https://raw.githubusercontent.com/mdhabeebvulla/samples/master/datasetsiris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5107 (5.0K) [text/plain]
# Saving to: ‘datasetsiris.csv’
#
# datasetsiris.csv    100%[===================>]   4.99K  --.-KB/s    in 0s
#
# 2024-01-17 22:17:58 (71.3 MB/s) - ‘datasetsiris.csv’ saved [5107/5107]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('datasetsiris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.plot(kind = 'scatter',x ='SepalLengthCm',y = 'SepalWidthCm' )
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
x = iris.iloc[:,1:5]
y = iris.iloc[:,5]

# %%
print(x)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
print(y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
# As explained in class, how to mount Drive and read datasets directly
# NOTE: Below Dataset is not available for everyone as it is practiced in class
# datampg = pd.read_csv('/content/drive/MyDrive/autompg.data',sep = '\s+',header=None)
# datampg.head()

# %%
plt.plot(iris['SepalLengthCm'],iris['SepalWidthCm'],'*', color ='b')
plt.xlabel('SeplaLength')
plt.ylabel('Sepalwidth')
plt.show()

# %%
data = iris.iloc[:,1:6]
sns.pairplot(data)
plt.show()

# %%
sns.boxplot('Species','PetalLengthCm',palette = 'husl',data = iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-89c093b46f9d> in <cell line: 1>()
# ----> 1 sns.boxplot('Species','PetalLengthCm',palette = 'husl',data = iris)
#       2 plt.show()
#
# TypeError: boxplot() got multiple values for argument 'data'

# %%
# !wget https://cdn.iisc.talentsprint.com/CDS/Datasets/advertising.csv
# Out:
# --2024-01-17 22:20:16--  https://cdn.iisc.talentsprint.com/CDS/Datasets/advertising.csv
# Resolving cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)... 172.105.52.210
# Connecting to cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)|172.105.52.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4062 (4.0K) [application/octet-stream]
# Saving to: ‘advertising.csv’
#
# advertising.csv     100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-01-17 22:20:17 (2.17 GB/s) - ‘advertising.csv’ saved [4062/4062]

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(df['TV'],df['Radio'],df['Sales'],c='m')
plt.show()

# %%
sns.pairplot(iris.drop('Id',axis=1),hue='Species',palette='husl',size=3)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121)
ax1.scatter(iris['PetalLengthCm'],iris['SepalLengthCm'])
ax2 = fig.add_subplot(122)
ax2.scatter(iris['PetalLengthCm'],iris['SepalLengthCm'])
plt.show()
